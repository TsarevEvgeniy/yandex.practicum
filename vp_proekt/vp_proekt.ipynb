# %% [markdown]
#  <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:#bdc3c7; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <h7 style="color:black; margin-bottom:20px"> Евгений, привет!
#
# Мои комментарии и замечания далее по тексту помечены различными цветами:
#
# ---
# <div class="alert alert-block alert-danger">
# ⁉️ : Критическое замечание, которые следует исправить.
# </div>
#
# <div class="alert alert-block alert-warning">
# ✏️ : Рекомендация\совет на будущее.
# </div>
#
# <div class="alert alert-block alert-success">
# ✔️ : Когда всё сделано правильно.
# </div>
#
# ---
#
# Хорошей практикой является оставлять свои комментарии после исправлений замечаний или для вопросов, разъяснений. Для того чтобы мне было легче их найти, то выделяй, пожалуйста, с помощью цвета, например вот так:
#
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#
# Вопрос, который не останется незамеченным
#
# </div>
#
# ---
#
# **В рамках финального спринта у вас есть лимит на количество итераций проверок. Я буду для информативности их отмечать в итоговом ревью:**
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# **`[1/6]`**
#
# Итог ревью - ...
#
# </div>
#
# p.s.: не удаляй мои замечания, если предстоит что-то доработать в проекте.</h7>

# %% [markdown]
# ---
#
# <div id="1" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⚠️ ИТОГИ РЕВЬЮ ⚠️ : </b>
#
# **`[1/6]`**
#
# <s>К сожалению, я не смог провести полную проверку, т.к. падает код. Я постарался провести ревью до этого момент, но имей ввиду, что при повторной проверке (когда код заработает), могут появиться и другие замечания.
#
#  - [Ошибка №1](#div_id1)
#
#  - [Ошибка №2](#div_id2)
#
#  - [Ошибка №3](#div_id3)
#
#  - [Ошибка №4](#div_id4)
#
#  - [Ошибка №5](#div_id5)
#
#  - [Ошибка №6](#div_id6)
#
#
# </div>
#
#
#
# <div id="2" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⚠️ ИТОГИ РЕВЬЮ ⚠️ : </b>
#
# **`[2/6]`**
#
# <s>В целом, проделана неплохая работа, но мне кажется тебе необходимо пересмотреть материалы созвона. В презентации были отмечены основные ошибки (которые часто встречались в проектах прошлых когорт).
#
# Структура и логика проекта корректные. Исследовательский этап проведен на хорошем уровне, многие метрики рассчитаны правильно. Вопросы заказчика представлены в полном объеме, но необходимо доработать отдельные пункты. Есть вопросы на этапе проверки гипотез.
#
# Я отметил критические моменты.
#
#  - [Ошибка №8](#div_id8)
#
#  - [Ошибка №9](#div_id9)
#
#  - [Ошибка №10](#div_id10)
#
#  - [Ошибка №11](#div_id11)
#
#  - [Ошибка №12](#div_id12)
#
#  - [Ошибка №13](#div_id13)
#
#  - [Ошибка №14](#div_id14)
#
#  - [Ошибка №15](#div_id15)
#
# Посмотри, пожалуйста, мои замечания и рекомендации.
#
# </div>
#
# <div id="3" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⚠️ ИТОГИ РЕВЬЮ ⚠️ : </b>
#
# **`[3/6]`**
#
# <s>Привет. Спасибо за доработки, но остались еще моменты, которые требуют твоего внимания.
#
#
#  - [Ошибка №16](#div_id16)
#
#  - [Ошибка №17](#div_id17)
#
#  - [Ошибка №18](#div_id18)
#
#  - [Ошибка №19](#div_id19)
#
#
# </div>
#
# <div id="4" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⚠️ ИТОГИ РЕВЬЮ ⚠️ : </b>
#
# **`[4/6]`**
#
# <s>Привет. Осталось доработать 2 пункты и смогу принять проект
#
#
#  - [Ошибка №20](#div_id20)
#
#  - [Ошибка №21](#div_id21)
#
#
#
# </div>
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> 🚀 ИТОГИ РЕВЬЮ 🚀 : </b>
#
# Привет! Проект полностью выполнен. Все важные моменты представлены.
#
# ---
#
# ![](https://media.giphy.com/media/xUKrrEnN9I5lnrcSMv/giphy-downsized-large.gif)
#
# ---
#
#
# Работу принимаю, чтобы открылся следующий проект. Но тебе необходимо будет отправить мне на проверку презентацию
#
# ---
#
# Остался последний шаг - SQL!
#
# </div>
#
# ---

# %% [markdown]
# # Выявление профилей потребления.

# %% [markdown]
# ## Материалы:
# *[Презентация](https://disk.yandex.ru/i/GfNHPflmR-7hlw)

# %% [markdown]
# Введение: Интернет-магазин товаров для дома «Пока все ещё тут» в срочном порядке ищет аналитиков.
# Наши задачи — выявление профилей покупателей, а также полноценный анализ товарного ассортимента. «Пока все ещё тут» — мы создаём уют!

# %% [markdown]
# Цель работы: предоставить комплексный анализ и рекомендации, которые позволят увеличить продажи и лояльность клиентов путем сегментированного маркетинга.

# %% [markdown]
# Описание данных
# Датасет описывает транзакции интернет-магазина товаров для дома и быта «Пока все ещё тут».
#
# date — дата заказа;
# customer_id — идентификатор покупателя;
# order_id — идентификатор заказа;
# product — наименование товара;
# quantity — количество товара в заказе;
# price — цена товара.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида : </b>
#
# Очень хорошо, что представлено описание работы и данных, обозначены цели исследования. Так будет сразу понятно о чем проект.
#
# </div>

# %% [markdown]
# План работы:
#
# Шаг 1. Откроем файл с данными и изучим общую информацию
#
# Шаг 2. Подготовим данные
#
# Заменим названия столбцов (приведем их к нижнему регистру)
#
# Преобразуем данные в нужный тип.
#
# Обработаем пропуски при необходимости
#
# Проверим на наличие явных и не явных дубликатов и обработать их
#
# Шаг 3. Проведем исследовательский анализ данных.
#
# Проведем категоризацию товаров
#
# Проверим динамику выручки
#
# Проверим средний чек и его динамеку
#
# Проверим помесячную динамику средней выручки с покупателя
#
# Шаг 4. основные вопросы исследования.
#
# Сегментация покупателей (RFM анализом)
#
# Проанализировать сегменты (количество покупателей, средний чек, основные продукты и категории)
#
# Проанализировать категорию товаров и их сезонность по выделенным сегментам покупателей.
#
# Шаг 5. Сформулировать гипотезы по сегментам.
#
# Первая гипотеза: Проверка разницы среднего чека между сегметами: H0 - Средний чек различных сегметов равен. H - Средний чек различных сегментов не равны.
#
# Вторая гипотиза: Проверка разницы выручки между сегментами:H0 - выручка различных сегметов пользователей равна. H- Выручка сегментов пользователей не равна.

# %% [markdown]
# Импортирем необходимые библиотеки.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import numpy as np
from scipy import stats
from scipy.stats import ttest_ind
from scipy import stats as st

# %% [markdown]
# # Шаг 1. Откроем файл с данными и изучим общую информацию.

# %% [markdown]
# <font color='black'><b> 1.1 Загружаем данные о транзакциях интернет-магазина товаров для дома и быта «Пока
# все ещё тут» из CSV-файлов в переменную. </b></font><br>

# %%
data = pd.read_csv('https://code.s3.yandex.net/datasets//ecom_dataset_upd.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/521552714.py in <module>
# ----> 1 data = pd.read_csv('https://code.s3.yandex.net/datasets//ecom_dataset_upd.csv')
#
# NameError: name 'pd' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/3870928973.py in <module>
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %% [markdown]
# <font color='black'><b> 1.2 Посмотрим обшую информацию датасета </b></font><br>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   int64
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 350.5+ KB

# %% [markdown]
# При рассмотрении общей информации можно сказать что датасет имеет 7473 строк.

# %% [markdown]
# Вывод по шагу №1: Мы загрузили датасет о транзакциях интернет-магазина. Заисали его в переменную data. После чего посмотрели обшую информацию датафрейма.

# %% [markdown]
# # Шаг 2. Подготовим данные.

# %% [markdown]
# <font color='black'><b> 2.1 Заменим названия столбцов (приведем их к нижнему регистру). </b></font><br>

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# <font color='black'><b> 2.2 Преобразуем данные в нужный тип: преобразуем столбец с датой. </b></font><br>

# %%
data['date'] = pd.to_datetime(data['date'],  format='%Y%m%d%H')

# %% [markdown]
# Посмотрим, что получилось

# %%
data.head()
# Out:
#         date                           customer_id  order_id  \
# 0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0

# %% [markdown]
# <font color='black'><b> 2.3 Проверим количество пропусков в каждом датасете </b></font><br>

# %%
data.isna().sum()
# Out:
# date           0
# customer_id    0
# order_id       0
# product        0
# quantity       0
# price          0
# dtype: int64

# %% [markdown]
# Пропусков в датасете не обнаружено

# %% [markdown]
# <font color='black'><b> 2.3 Проверим на наличие явных и не явных дубликатов </b></font><br>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не обнаруженно.

# %% [markdown]
# Проверим на наличие не явных дубликатов

# %%
# Убираем колонку date для проверки системы логирования
key_columns = ['customer_id', 'order_id', 'product']  

# Ищем дубликаты
duplicates = data.duplicated(subset=key_columns, keep=False)

# Фильтруем только строки с дубликатами
duplicate_rows = data[duplicates]

# Выводим результат
print(f"Количество неявных дубликатов: {duplicate_rows.shape[0]}")

# Удаляем дубликаты
data = data.drop_duplicates(subset=key_columns, keep='first')

# Проверяем результат
print(f"Данные после удаления дубликатов: {data.shape[0]} строк")
# Out:
# Количество неявных дубликатов: 2393
# Данные после удаления дубликатов: 5588 строк

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✏️ Рекомендация тимлида : </b>
#
# Да, важно осуществить проверку данных на предмет неявных дубликатов (не по всем!, а по ключевым колонкам через `subset` - например по `order_id`, 'customer_id' и содержимому заказов без колонки `date`, чтобы проверить систему логирования).
#
# ---
#
# Можно было проверить предположение, что при добавлении новой товарной позиции в заказ, старая дублируется и тогда можно старые данные безболезненно удалить.
#
#
# </div>

# %% [markdown]
# Мы проверили неявные дубликаты по order_id, 'customer_id' и содержимому заказов. Это явная ошибка сбора данных, поэтому мы удаляем данные дубликаты.

# %% [markdown]
# Проверим на наличие заказов совершенных более чем одним покупателем

# %% [markdown]
# Для начала посмотрим сколько покупателей в каждом заказе, и отсортируем тех где больше одного покупателя в закзе.

# %%
order_id = (
    data.groupby('order_id')['customer_id']
    .nunique()
    .loc[lambda x: x > 1] 
    .sort_values(ascending=False)
)

# %%
order_id
# Out:
# order_id
# 72845    4
# 69485    3
# 71480    3
# 14872    2
# 70946    2
# 72790    2
# 72778    2
# 72188    2
# 71663    2
# 71648    2
# 71571    2
# 71542    2
# 71461    2
# 71226    2
# 71054    2
# 70903    2
# 68785    2
# 70808    2
# 70726    2
# 70631    2
# 70542    2
# 70114    2
# 69833    2
# 69531    2
# 69410    2
# 69345    2
# 69310    2
# 69283    2
# 72950    2
# Name: customer_id, dtype: int64

# %% [markdown]
# Данные заказы не коректны, так как не может быть двух покупателей в одном заказе. Это явная ошибка сбора данных, поэтому нам необходимо удалить данные строки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %%
# Получаем список order_id, которые нужно удалить
order_id_udal = order_id.index.tolist()

# Удаляем строки, где order_id входит в список для удаления
data = data[data['order_id'].isin(order_id_udal) == False]

# Проверяем обновленный DataFrame
print(f"Обновленные данные: {data.shape[0]} строк")
# Out:
# Обновленные данные: 5522 строк

# %% [markdown]
# Посмотрим на общую информацию после обработки.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5522 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         5522 non-null   datetime64[ns]
#  1   customer_id  5522 non-null   object
#  2   order_id     5522 non-null   int64
#  3   product      5522 non-null   object
#  4   quantity     5522 non-null   int64
#  5   price        5522 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 302.0+ KB

# %% [markdown]
# Вывод по шагу №2: Мы заменили названия столбцов (привели их к нижнему регистру). Проверили количество пропусков в каждом датасете, их мы не обнаружили. Проверили количество явных дубликатов их мы не обнаружили. Мы проверили неявные дубликаты по order_id, 'customer_id' и содержимому заказов. Это явная ошибка сбора данных, поэтому мы удаляем данные дубликаты. Мы решили их просто удалить, так это не повлияет на наше иследование. Так же мы убрали заказы, где более одного покупателя.

# %% [markdown]
# <div id="div_id1" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №1](#1)
#
# Стоит еще проверить на наличие заказов совершенных более чем одним покупателем. Такие заказы некорректны.
#
# </div>

# %% [markdown]
# # Шаг 3. Проведем исследовательский анализ данных.

# %% [markdown]
# Добавим столбец с прибылью по заказу.

# %%
# Добавляем столбец с чеком
data['chek'] = data['quantity'] * data['price']

# %%
# Группировка по order_id и суммирование чеков
order_totals = data.groupby('order_id')['chek'].sum().sort_values(ascending=False)
order_totals.head()
# Out:
# order_id
# 71743    675000.0
# 71668     49432.0
# 69830     47385.0
# 69156     33680.0
# 69504     32718.0
# Name: chek, dtype: float64

# %%
plt.figure(figsize=(5, 5))
plt.boxplot(order_totals)
plt.title("Диаграмма размаха выручек с заказов")
plt.ylabel("Выручка с заказа")
plt.show()

# %% [markdown]
# Мы видим выброс с чеком 675 000 рублей. Далее идет чек с более менее приемлемыым значением относительно остальных: 49432. Считаю, что это значение уже не является аномальным.

# %% [markdown]
# <div id="div_id7" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №7](#2)
#
# ![image.png](attachment:image.png)
#
# Это не может быть порядковым номером пользователя, т.к. их всего 2413
#
# ![image-3.png](attachment:image-3.png)
#
# </div>

# %% [markdown]
# <div id="div_id8" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2]: </b>
#
# <s>[⬆ Ошибка №8](#2)
#
# Как ты определил конкретный номер id аномального заказа? По графику это невозможно сделать
#
# ---
#
# В целом, по выбросам:
#
# Выбросы стоит смотреть по чеку покупки. Т.к. чек покупки содержит в себе информацию как о количестве товаров, так и о его цене.
#
# Так же стоит смотреть выбросы по количеству заказов на покупателя. Возможно там есть аномальные данные?
#
# Сразу на будущее, при выделении выбросов используй процентили, а не ручную подстановку. Необходимо стараться автоматизировать процессы исследования.
#
# ---
#
# Важно помнить, что **не все выбросы являются аномалией**.
#
# "Выбросы — это значения в данных, которые заметно отличаются от основной массы наблюдений. Проблема выбросов в том, что они могут повлиять на выводы, которые делаются на основе данных.
#
# Важно помнить, что выбросы следует удалять только в случае явных ошибок или при необходимости сфокусироваться на «общем» тренде. В противном случае вы потеряете важную информацию, которая может оказаться ценной для понимания редких или уникальных явлений в данных"
#
#
# </div>

# %% [markdown]
# Я сделал 99.99 процентиль, что бы автоматически отсеить значение 675 000 рублей но не задеть 49432 рублей. Методом подбора! С новыми данными данный алгоритм работать не будет.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v4] : </b>
#
#     С новыми данными данный алгоритм работать не будет.
#
# Нет универсального и идеального способа.  Даже если бы отбросил 49432 было бы корректным решением.
#
# Как я говорил, важен сам подход.
#
# ---
#
# Если интересно можно изучить подробнее `IsolationForest` для выявления выбросов в зависимости от того, какими данными располагаем.
#
# ![image.png](attachment:image.png)
#
# </div>

# %%
perc_99 = np.percentile(order_totals, 99.99)
perc_99
# Out:
# 456614.21119977336

# %% [markdown]
# Будем считать все заказы дороже 99.99 процентили выбросами. Выделим их order_id и посчитаем количество:

# %%
# Выбор order_id, где сумма чеков меньше 99.99-го процентиля
outlier_orders = order_totals[order_totals > perc_99].index
len(outlier_orders)
# Out:
# 1

# %% [markdown]
# <div id="div_id16" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v3] : </b>
#
# <s>[⬆ Ошибка №16](#3)
#
#     Будем считать все заказы дороже 99 процентили выбросами
#
# Почему? Я же написал в прошлом замечании
#
#     Важно помнить, что не все выбросы являются аномалией
#
#
# Посмотри на эти заказы - они разве все аномальные?
#
# </div>

# %% [markdown]
# Удалим данные заказы.

# %%
# Исключение выбросов из исходного DataFrame
data = data[~data['order_id'].isin(outlier_orders)]

# %% [markdown]
# Посмотрим выбросы по количеству заказов на покупателя.

# %%
# Считаем количество заказов на покупателя
kol_zak = data.groupby('customer_id')['order_id'].nunique().reset_index()


# Сортируем по убыванию и выводим топ-50
kol_zak = kol_zak.sort_values(by='order_id', ascending=False)
kol_zak.head()
# Out:
#                                customer_id  order_id
# 1884  c971fb21-d54c-4134-938f-16b62ee86d3b       126
# 729   4d93d3f6-8b24-403b-a74b-f5173e40d7db        35
# 1079  73d1cd35-5e5f-4629-8cf2-3fda829d4e58        17
# 1718  b7b865ab-0735-407f-8d0c-31f74d2806cc         7
# 17    0184f535-b60a-4914-a982-231e3f615206         5

# %% [markdown]
# Посмотрим клиента c971fb21-d54c-4134-938f-16b62ee86d3b, с большим количеством заказов.

# %%
# Фильтрация по `customer_id`
customer_id_to_filter = "c971fb21-d54c-4134-938f-16b62ee86d3b"
filtered_df = data[data["customer_id"] == customer_id_to_filter]
filtered_df.head()
# Out:
#                    date                           customer_id  order_id  \
# 9   2018-10-01 09:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68480
# 20  2018-10-02 08:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68490
# 64  2018-10-03 08:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68511
# 65  2018-10-03 10:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68514
# 130 2018-10-08 07:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68561
#
#                                                product  quantity   price  \
# 9    Чехол для гладильной доски Colombo Persia Beig...         1   674.0
# 20   Чехол для гладильной доски Festival 137x60 см ...         1  1162.0
# 64   Набор прищепок большие пластиковые ROZENBAL ПИ...        10    86.0
# 65   Сушилка для белья Attribute ПРИМА 11 м синяя н...         1   749.0
# 130  Тележка багажная DELTA ТБР-20 коричневый с ора...         1   742.0
#
#        chek
# 9     674.0
# 20   1162.0
# 64    860.0
# 65    749.0
# 130   742.0

# %%
# Суммируем покупки по дате
filtered_df["date"] = pd.to_datetime(filtered_df["date"])  # Преобразуем дату в формат datetime
grouped = filtered_df.groupby("date").sum(numeric_only=True)["chek"]

# Построение графика
plt.figure(figsize=(10, 6))
plt.plot(grouped.index, grouped.values, marker='o', linestyle='-', color='b', label="Сумма покупок")
plt.title("Сумма покупок по датам для пользователя", fontsize=14)
plt.xlabel("Дата", fontsize=12)
plt.ylabel("Сумма покупок (₽)", fontsize=12)
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Показ графика
plt.show()

# %% [markdown]
# Мы видим, что заказы были на протежении большого количества времени, получается что эти заказы не является ошибкой. Но так как этот заказ покупателей сильно отличается от остальных и может вносить искажения в расчеты, мы удалим его, для более массового покупателя.

# %%
# Найти 99.99-й процентиль
percentile_99 = np.percentile(kol_zak['order_id'], 99.99)

# Оставить только строки, где 'order_count' меньше 99.99-го процентиля
filtered_customer_orders = kol_zak[kol_zak['order_id'] > percentile_99]
len(filtered_customer_orders)
# Out:
# 1

# %%
filtered_customer_orders.head()
# Out:
#                                customer_id  order_id
# 1884  c971fb21-d54c-4134-938f-16b62ee86d3b       126

# %% [markdown]
# Удаляем данного покупателя

# %%
data = data[~data['customer_id'].isin(filtered_customer_orders['customer_id'])]

# %% [markdown]
# <div id="div_id17" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v3] : </b>
#
# <s>[⬆ Ошибка №17](#3)
#
# ![image.png](attachment:image.png)
#
#
# Ничего не понял.
#
# 99-й процентиль у тебя равен 3. Ты оставляешь только покупателей у которых один или два заказа. Ты уверен в этом? Что аномального в покупателе, который сделал 5 заказов? 7?
#
# ---
#
# Потом ты фильтруешь покупателей по этому процентилю
#
#     # Оставить только строки, где 'order_count' меньше 99-го процентиля
#     filtered_customer_orders = kol_zak[kol_zak['order_id'] < percentile_99]
#
# А потом ты фильтруешь `order_id` в основном датафрейме? Так у тебя в этой таблице `order_id` - количество заказов у покупателя.
#
#           data = data.query('order_id not in @sorted_customer_orders')
#
# ![image-2.png](attachment:image-2.png)
#
# Если и фильтровать то покупателей - `customer_id`
#
# </div>

# %% [markdown]
# <div id="div_id9" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2]: </b>
#
# <s>[⬆ Ошибка №9](#2)
#
# Не совсем понимаю логику действий.
#
# Ты удалил аномальный заказ, а потом данные без аномального заказа еще и фильтруешь? Зачем?
#
#
#
# </div>

# %% [markdown]
# <div id="div_id10" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №10](#2)
#
# Подставлять вручную данные - плохая практика.
#
# Чтобы сделать свой проект устойчивым к изменениям и более профессиональным, рекомендую автоматизировать процесс подстановки данных. Это избавит от необходимости вручную обновлять их в будущем и сделает твой проект воспроизводимым.
#
# ---
#
# Пожалуйста, просмотри весь проект и внеси необходимые коррективы там, где это требуется.
#
# </div>

# %% [markdown]
# Мы убрали выбросы которые увидели в чеке заказа, а так же убрали  выбросы по количеству заказов на покупателя.

# %% [markdown]
# <div id="div_id2" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №2](#1)
#
# Нет отработки аномальных данных.
#
# Перед исследовательским этапом данные должны быть подготовлены
#
# </div>

# %% [markdown]
# <font color='black'><b> 3.1 Проведем категоризацию товаров </b></font><br>

# %%
data['product'].sort_values().unique().tolist()
# Out:
# ['Tepмокружка AVEX Freeflow 700 мл зеленый AVEX0759',
#  'Tepмокружка AVEX Freeflow 700 мл сталь AVEX0776',
#  'Tepмокружка AVEX Recharge 500 мл голубой AVEX0681',
#  'Ёрш бутылочный с металлической ручкой малый Y64 1807002',
#  'Ёрш для бутылки из натурального волокна и металла 23 см кремовый, Burstenmann, 0473/0003',
#  'Ёрш радиаторный без ручки 1807007',
#  'Ёрш унитазный пластмассовый, Ваир 1712002',
#  'Ёрш унитазный с деревянной ручкой , Ваир 1712012',
#  'Ёрш унитазный с подставкой WC "Люкс", Мультипласт, 1712007',
#  'Ёрш унитазный с подставкой WC "Стандарт", Мультипласт 1712010',
#  'Автоматическая щетка Leifheit для мытья окон с ручкой 43 см. 51114',
#  'Агератум рассада однолетних цветов в кассете по 10 шт',
#  'Адиантум Лиза d-12 см',
#  'Азалия Индика Биколор d-12 см h-20',
#  'Азалия Индика розовая d-12 см h-20',
#  'Азалия Индика фиолетовая d-10 см h-20',
#  'Азалия индика Биколор d-12 см',
#  'Аквилегия махровая Тауэр смесь окрасок объем 1 л',
# ...

# %%
list_products = {
    
    'Кухонные аксессуары':['банка', 'кастрюля', 'столов', 'емкость', 'посуд', 'блюд', 'разделочн', 'выпечк', 'кухонн', 'весы настол', 
                 'сковород', 'овощ', 'бидон', 'Tepмокружка', 'коврик интерьерн', 'для свч', 'кружка', 'салфет', 'скатерт',
                 'дуршлаг', 'контейнер', 'картофел', 'luminarc', 'кувшин', 'венчик', 'кипятильник', 'крышка', 'чайн',
                 'лоток', 'салатник', 'webber', 'миксер', 'нож', 'фужер', 'стакан', 'миска', 'viva', 'лопатка', 'мантоварка',
                 'отделитель', 'scovo', 'рыбочистка', 'сахарница'],
    
    'Товары для ванной':['для ванн', 'влаговпит', 'туалет', 'ванна 70 л', 'зубная паста', 'для мыла', 'бельев', 'коврик противоскол',
                 'унитаз', 'мыло', 'в ванну', 'для бель', 'ковш', 'корзин', 'стирк', 'полотен', 'коврик', 'зубн',
                 'мыльн', 'прищепок', 'отбеливател', 'ржавчин', 'штора'],
    
    'Сад и огород':['рассада', 'd-13', 'd-12', 'd-7', 'd-27', 'd-21', 'd-17 ', 'цветущ', 'd-15', 'd-10', 'ампельная',  
                'в горшк', 'вербена', 'гвоздика', 'капуста', 'пеларгония', 'калибрахоа', 'd-9', 'р-9', 'd-5', 
                'календул', 'клубника', 'однолетн', 'многолетн', 'объем 0,5 л', 'в упаковке', 'крупноцвет',
                'укоренен', '0,1 г', 'космея', 'раннеспел', 'нидерланд', 'кашпо', 'обыкновен', '0,3 г', 'объем',
                'настурция', 'зверобой', 'лук', 'фиалка', 'кориандр', 'в кассете', 'ель канадская', 'мирт', 'бегония',
                'георгина', 'горох', 'пуансеттия', 'алиссум', 'вербейник', 'девичий виноград', '0,04 г', '0,02 г',
                'львиный', 'морковь', 'флокс', 'томат', 'базилик', 'рукола', 'корыто'],
    
    'Чистота и порядок':['мытья', 'веник', 'вантуз', 'ведр', 'губк', 'мусор', 'утюг', 'насадка', 'мойка', 'антижир', 'тряпкодержатель',
              'ткань', 'совок'],
    
    'Организация пространства':['вешалк', 'гладильн', 'хранен', 'короб', 'кофр', 'крючок', 'набор вешалок', 'гладильная доск',
                      ],
    
    'Украшение дома':['искусственн', 'декоративн', 'ваза', 'муляж'],
    
    'Домашний уют':['придверный', 'напольн', 'ключница', 'карниз', 'постельн', 'комод', 'дверн', 'обувн', 'wellness',
                'одеяло', 'наматрац', 'наматрицник', 'форточн', 'светильник', 'стеллаж'],
    
    'Инструменты и гор.жидкости':[ 'веревк', 'инструмент', 'для полировки', 'набор сверел', 'угольник',
                'напильник', 'основание', 'линейка', 'бензин', 'сверло','стремянка','тележка', 'котел','сумка-тележка']
    
}

# %% [markdown]
# <div id="div_id3" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание ревьюера : </b>
#
# <s>[⬆ Ошибка №3](#1)
#
# `бензин` и `напильник` - это Домашний уют?
#
# Предлагаю пересмотреть логику категоризации товаров и перепроверить другие категории
#
# </div>

# %% [markdown]
# Сделаем функцию для присвоения категории товару.

# %%
def categor_product(product):

    for category, items_products in list_products.items():
        for item in items_products:
            if item in product:
                return category
    return category

# %% [markdown]
# Добавим столбец категории

# %%
data['categor'] = data['product'].apply(categor_product)

# %%
data.head()
# Out:
#         date                           customer_id  order_id  \
# 0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price   chek  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0  112.0
#
#         categor
# 0  Сад и огород
# 1  Сад и огород
# 2  Сад и огород
# 3  Сад и огород
# 4  Сад и огород

# %% [markdown]
# Проверим, что нет незаполненых категорий.

# %%
data['categor'].sort_values().unique().tolist()
# Out:
# ['Домашний уют',
#  'Инструменты и гор.жидкости',
#  'Кухонные аксессуары',
#  'Организация пространства',
#  'Сад и огород',
#  'Товары для ванной',
#  'Украшение дома',
#  'Чистота и порядок']

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# <font color='black'><b> 3.2 Проверим динамику выручки </b></font><br>

# %% [markdown]
# Группируем по месяцам и  делаем расчет выручки

# %%
data['month'] = data['date'].dt.to_period('M')  # Добавляем столбец с месяцами
monthly_revenue = data.groupby('month')['price'].sum()

# %% [markdown]
# Построение графика

# %%
plt.figure(figsize=(10, 6))
monthly_revenue.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Динамика выручки по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Выручка (₽)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Расчёт динамики выручки выполнен успешно.
#
# </div>

# %% [markdown]
# Вывод: Если смотреть на выручку компании, то мы видим, что она была максимальная в октябре 2018, затем было падение в январе и постепенный рост до июня 2019 года. после чего выручка стала падать с заметным провалом в ноябре и больше не востановилась

# %% [markdown]
# Считаем средний чек

# %%
chek = data.groupby(['month', 'order_id']).agg({'chek': 'sum'})
chek = chek.groupby('month').agg({'chek': 'mean'}).round(0)
chek
# Out:
#            chek
# month
# 2018-10  1488.0
# 2018-11  1817.0
# 2018-12  1285.0
# 2019-01  1392.0
# 2019-02  1009.0
# 2019-03  1029.0
# 2019-04  1199.0
# 2019-05  1314.0
# 2019-06  1443.0
# 2019-07  1187.0
# 2019-08  1001.0
# 2019-09   994.0
# 2019-10  1032.0
# 2019-11   594.0
# 2019-12   825.0
# 2020-01   647.0

# %% [markdown]
# Строим график

# %%
ax = chek.plot(kind='barh', figsize=(10, 6), color='royalblue', edgecolor='darkblue')
ax.set_title('Динамика среднего чека по месяцам', fontsize=16, fontweight='bold')
ax.set_xlabel('Средний чек (₽)', fontsize=12)
ax.set_ylabel('Месяц', fontsize=12)
ax.grid(axis='x', linestyle=':', alpha=0.9)
plt.tight_layout()
plt.show()

# %% [markdown]
# Вывод: Если смотреть на средний чек по месяцам, то мы видим, что он уменьшается и не востанавливается.

# %% [markdown]
# <div id="div_id4" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание ревьюера : </b>
#
# <s>[⬆ Ошибка №4](#1)
#
#     По какой то причине средний чек в июне был максимальный.
#
# Это задача аналитика разобраться по какой причине
#
# </div>

# %% [markdown]
# <font color='black'><b> 3.4 Проверим помесячную динамику средней выручки с покупателя. </b></font><br>

# %% [markdown]
# Сгруппируем по месяцу и customer_id, расчет суммы выручки с каждого покупателя

# %%
month_customer = data.groupby(['month', 'customer_id'])['chek'].sum().reset_index()

# %%
sr_month_customer = month_customer.groupby('month')['chek'].mean()

# %% [markdown]
# <div id="div_id5" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание ревьюера : </b>
#
# <s>[⬆ Ошибка №5](#1)
#
# `price` - это единичная цена товара. Ты не учитываешь в выручке количество проданного товара
#
# </div>

# %% [markdown]
# Строим график

# %%
plt.figure(figsize=(10, 6))
sr_month_customer.plot(kind='line', marker='o', color='green')
plt.title('Помесячная средняя выручка с покупателя')
plt.xlabel('Месяц')
plt.ylabel('Средняя выручка (₽)')
plt.grid(True)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# Вывод: мы видим как средняя выручка с покупателя уменьшается.

# %% [markdown]
# Вывод по шагу №3: Можно сделать вывод, что у магазина есть проблемы с продажами: выручка уменьшается по сравнению с октябрем 2018 года, средний чек так же продолжает падение и в последние три месяца на минимуме. Если посмотреть на динамику среднего чека с покупателя то видим, что она падает.

# %% [markdown]
# # Шаг 4. основные вопросы исследования.

# %% [markdown]
# <font color='black'><b> 4.1 Сегментация покупателей (RFM анализом) </b></font><br>

# %% [markdown]
# Суть RFM-анализа – разделять клиентов в зависимости от того, как давно они сделали покупку, как часто они ее делали и сколько денег потратили. Каждый признак мы можем разделить еще на 3 подгруппы.
#
# Для Recency это выглядит следующим образом:
#
# 1 – клиенты, которые совершали покупки очень давно;
#
# 2 – относительно недавние клиенты;
#
# 3 – только пришедшие клиенты.
#
# Frequency:
#
# 1 – клиент совершает очень мало покупок, обычно не превосходит единоразового визита;
#
# 2 – клиент приходит за покупками, но крайне редко;
#
# 3 – постоянный покупатель, который часто взаимодействует с продуктом.
#
# Monetary:
#
# 1 – небольшая сумма покупки;
#
# 2 – средние затраты;
#
# 3 – крупная сумма, которую потратил клиент на товар или услугу компании.

# %% [markdown]
# Так как нам надо разделить на три группы, я решил, что лучше выбрать 33 и 67 процентили, так как это делит сегменты на равыне доли. Я думаю что так будет удобнее сравнивать.

# %%
#извлекаем столбцы
temp=['customer_id', 'order_id', 'date', 'chek']
rfm_data=data[temp]
rfm_data.shape
# Out:
# (5378, 4)

# %%
rfm_data.head()
# Out:
#                             customer_id  order_id       date   chek
# 0  ee47d746-6d2f-4d3c-9622-c31412542920     68477 2018-10-01  142.0
# 1  ee47d746-6d2f-4d3c-9622-c31412542920     68477 2018-10-01  194.0
# 2  ee47d746-6d2f-4d3c-9622-c31412542920     68477 2018-10-01  112.0
# 3  ee47d746-6d2f-4d3c-9622-c31412542920     68477 2018-10-01  179.0
# 4  ee47d746-6d2f-4d3c-9622-c31412542920     68477 2018-10-01  112.0

# %%
pd.options.mode.chained_assignment = None #убираем ошибку

NOW = dt.datetime(2020,1,31)
#Convert date to datetime format.
rfm_data['date'] = pd.to_datetime(rfm_data['date'])
# rfm Table
rfm_table=rfm_data.groupby('customer_id').agg({'date': lambda x: (NOW - x.max()).days, # Recency
                                                'order_id': lambda x: len(x.unique()), # Frequency
                                                'chek': lambda x: x.sum() })   # Monetary 

rfm_table['date'] = rfm_table['date'].astype(int)

rfm_table.rename(columns={'date': 'recency', 
                         'order_id': 'frequency',
                         'chek': 'monetary_value'}, inplace=True)
rfm_table.head()
# Out:
#                                       recency  frequency  monetary_value
# customer_id
# 000d6849-084e-4d9f-ac03-37174eaf60c4      106          1           555.0
# 001cee7f-0b29-4716-b202-0042213ab038      348          1           442.0
# 00299f34-5385-4d13-9aea-c80b81658e1b      108          1           914.0
# 002d4d3a-4a59-406b-86ec-c3314357e498      368          1          1649.0
# 003bbd39-0000-41ff-b7f9-2ddaec152037      123          1          2324.0

# %%
quantiles = rfm_table.quantile(q=[0.33,0.67])
quantiles
# Out:
#       recency  frequency  monetary_value
# 0.33    103.0        1.0           522.3
# 0.67    303.0        2.0          1384.5

# %%
# Converting quantiles to a dictionary, easier to use.
quantiles = quantiles.to_dict()

##  rfm Segmentation ----
rfm_Segment = rfm_table.copy()
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)

# %%
def R_Class(x, p, d):
    if x <= d[p][0.33]: 
        return 3
    elif x <= d[p][0.67]: 
        return 2
    else:
        return 1

def FM_Class(x, p, d):
    if x <= d[p][0.33]:  
        return 1
    elif x <= d[p][0.67]: 
        return 2
    else:
        return 3

# %%
rfm_Segment['R_Quartile'] = rfm_Segment['recency'].apply(R_Class, args=('recency',quantiles,))
rfm_Segment['F_Quartile'] = rfm_Segment['frequency'].apply(FM_Class, args=('frequency',quantiles,))
rfm_Segment['M_Quartile'] = rfm_Segment['monetary_value'].apply(FM_Class, args=('monetary_value',quantiles,))
rfm_Segment['rfm'] = rfm_Segment.R_Quartile.map(str) \
                            + rfm_Segment.F_Quartile.map(str) \
                            + rfm_Segment.M_Quartile.map(str)

# %% [markdown]
# Смотрим сколько всего комбинаций:

# %%
rfm_Segment['rfm'].unique()
# Out:
# array(['212', '111', '113', '213', '323', '112', '321', '311', '322',
#        '233', '313', '211', '223', '123', '222', '121', '231', '312',
#        '221', '122', '232', '133', '131', '333'], dtype=object)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Здорово, что разобрался с RFM сегментацией. Сегменты выделены корректно
#
# </div>

# %% [markdown]
# Теперь сделаем описание сигментирования пользователей:

# %% [markdown]
# <font color='black'><b> Ушедшие клиенты: </b></font><br>

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['111', '112', '113'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# ee47d746-6d2f-4d3c-9622-c31412542920      487          1          1037.0
# 17213b88-1514-47a4-b8aa-ce51378ab34e      486          1          2374.0
# 161e1b98-45ba-4b4e-8236-e6e3e70f6f7c      486          1           820.0
# 375e0724-f033-4c76-b579-84969cf38ee2      486          1           824.0
# b731df05-98fa-4610-8496-716ec530a02c      486          1          3299.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# ee47d746-6d2f-4d3c-9622-c31412542920           1           1           2  112
# 17213b88-1514-47a4-b8aa-ce51378ab34e           1           1           3  113
# 161e1b98-45ba-4b4e-8236-e6e3e70f6f7c           1           1           2  112
# 375e0724-f033-4c76-b579-84969cf38ee2           1           1           2  112
# b731df05-98fa-4610-8496-716ec530a02c           1           1           3  113

# %% [markdown]
# Клиенты, которые приходят единоразово, совершают мало покупок и тратят на это как мало, так и много средств. Подобные клиенты, скорее всего, больше не вернутся к вам, поэтому не стоит тратить на них время. Для такого сегмента вы можете отправить реакционную рассылку.

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['121', '122', '123'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# f5c28991-8268-4e71-a71e-28b98a9ac5f9      478          2          1124.0
# 3de09660-90bc-4a28-aaf1-34c8435fe59c      469          2          2450.0
# 49b9c587-c19e-4481-bace-967aeac357fa      464          2          1352.0
# 1b09d659-6aff-4be8-b548-77e949f60309      460          2           606.0
# 8e7f282f-d919-4fc9-ada9-33dae8c2c76b      453          2           597.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# f5c28991-8268-4e71-a71e-28b98a9ac5f9           1           2           2  122
# 3de09660-90bc-4a28-aaf1-34c8435fe59c           1           2           3  123
# 49b9c587-c19e-4481-bace-967aeac357fa           1           2           2  122
# 1b09d659-6aff-4be8-b548-77e949f60309           1           2           2  122
# 8e7f282f-d919-4fc9-ada9-33dae8c2c76b           1           2           2  122

# %% [markdown]
# Такие клиенты совершают несколько покупок в разный период времени с разным бюджетом. В данном случае можно постараться вернуть клиентов с помощью рассылки. Например, можно отправить опрос и узнать, почему клиенты больше не пользуются вашими услугами.

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['131', '132', '133'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# 4d93d3f6-8b24-403b-a74b-f5173e40d7db      463         35         57278.0
# 639c4989-b0ab-412a-b7ec-be394cb2d372      451          3         12095.0
# f163e581-59ba-4022-99db-e0973c7497c0      450          3          2511.0
# 552e17df-ba16-4e66-84fb-55a5557a6bea      384          3          5398.0
# 5d566073-92e8-41d1-a2e6-d301ee5ab6d8      369          3           434.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# 4d93d3f6-8b24-403b-a74b-f5173e40d7db           1           3           3  133
# 639c4989-b0ab-412a-b7ec-be394cb2d372           1           3           3  133
# f163e581-59ba-4022-99db-e0973c7497c0           1           3           3  133
# 552e17df-ba16-4e66-84fb-55a5557a6bea           1           3           3  133
# 5d566073-92e8-41d1-a2e6-d301ee5ab6d8           1           3           1  131

# %% [markdown]
# Таким клиентам нравится ваш продукт и они готовы платить за него, но редко с ним взаимодействуют. Следует попытаться вернуть таких клиентов. Это можно сделать с помощью рассылки, в которой будет информация о скидках, программы лояльности и так далее.

# %% [markdown]
# <font color='black'><b> Неактивные клиенты: </b></font><br>

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['211', '212', '213','221','222','223'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# 8b8bd03f-a3c4-4e69-b39a-fd38013a1c03      303          1           352.0
# 190e21db-9be8-4c41-b14b-8e1510075e54      303          1           928.0
# feeaebd0-2c7c-4408-a75a-0081d395888f      303          1            84.0
# 34a0ed26-edc1-449b-9229-e0c199460721      303          1          5287.0
# 749cef81-0af4-4620-b880-6a728df5dfe8      303          1           925.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# 8b8bd03f-a3c4-4e69-b39a-fd38013a1c03           2           1           1  211
# 190e21db-9be8-4c41-b14b-8e1510075e54           2           1           2  212
# feeaebd0-2c7c-4408-a75a-0081d395888f           2           1           1  211
# 34a0ed26-edc1-449b-9229-e0c199460721           2           1           3  213
# 749cef81-0af4-4620-b880-6a728df5dfe8           2           1           2  212

# %% [markdown]
# Это относительно недавние клиенты, которые приходят единоразово и могут потратить разные суммы.  Такие клиенты были у вас недавно, поэтому еще помнят вас и, возможно, еще будут совершать покупки. Поэтому следует им напомнить о себе, например, сделать это можно с помощью рассылки, где будет указана информация о специальных предложениях, акциях и так далее.

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['231', '232', '233'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# eb6521ae-56e3-4a72-9ea2-e9c69701ff3f      296          3          2903.0
# 41117d9d-94f7-4145-a8c9-cb6675ce7674      293          3           574.0
# 7d64b4ea-d03f-4c3a-b283-21b3d0d237f1      291          3           938.0
# 498f12a4-6a62-4725-8516-cf5dc9ab8a3a      286          4         41900.0
# 7d0641a6-e043-487d-b356-38895fe7df84      282          3           522.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# eb6521ae-56e3-4a72-9ea2-e9c69701ff3f           2           3           3  233
# 41117d9d-94f7-4145-a8c9-cb6675ce7674           2           3           2  232
# 7d64b4ea-d03f-4c3a-b283-21b3d0d237f1           2           3           2  232
# 498f12a4-6a62-4725-8516-cf5dc9ab8a3a           2           3           3  233
# 7d0641a6-e043-487d-b356-38895fe7df84           2           3           1  231

# %% [markdown]
# Такие клиенты были у вас недавно и покупали довольно часто, но в один момент перестали с вами взаимодействовать. Следует обязательно выяснить, что случилось, почему клиент перестал у вас покупать. Вернуть таких клиентов можно с помощью опроса либо акционных предложений.

# %% [markdown]
# <font color='black'><b> Постоянные клиенты: </b></font><br>

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['311', '312', '313'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# 69c524f1-dd2a-4c4e-a5b0-def54dc96f9e      103          1           149.0
# 264bf7ec-cd01-4bf0-9c41-fc120c6cbdb5      103          1           157.0
# 7f965fe1-2d6a-4cb4-9832-90c824ac7bb0      102          1           742.0
# f5338bd4-e137-4f11-a863-843712202318      102          1           156.0
# 10f79846-2640-4c43-8392-4e76ff5455ef      102          1            22.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# 69c524f1-dd2a-4c4e-a5b0-def54dc96f9e           3           1           1  311
# 264bf7ec-cd01-4bf0-9c41-fc120c6cbdb5           3           1           1  311
# 7f965fe1-2d6a-4cb4-9832-90c824ac7bb0           3           1           2  312
# f5338bd4-e137-4f11-a863-843712202318           3           1           1  311
# 10f79846-2640-4c43-8392-4e76ff5455ef           3           1           1  311

# %% [markdown]
# Это совсем новые клиенты, которые недавно узнали о вас и готовы регулярно покупать ваши товары или услуги за небольшую или крупную сумму. Из этого сегмента можно выделить потенциальных VIP-клиентов. Следует отправить приветственное письмо и привить интерес к продукту.

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['321', '322', '323'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# 23ca02ae-37c2-420d-b893-26f9cb262188      102          2           440.0
# cdaf413b-09ae-48c0-8cfa-5cd6b71948c6       93          2           298.0
# 55f5aaea-0a3f-46c0-8677-e0d5be2d19ee       92          2          1858.0
# cb65d08a-dae7-4890-aef0-bb9f79055e02       92          2           261.0
# 6406e169-0238-44c4-8ab5-e20190778679       92          2           596.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# 23ca02ae-37c2-420d-b893-26f9cb262188           3           2           1  321
# cdaf413b-09ae-48c0-8cfa-5cd6b71948c6           3           2           1  321
# 55f5aaea-0a3f-46c0-8677-e0d5be2d19ee           3           2           3  323
# cb65d08a-dae7-4890-aef0-bb9f79055e02           3           2           1  321
# 6406e169-0238-44c4-8ab5-e20190778679           3           2           2  322

# %% [markdown]
# Таких клиентов можно считать постоянными. Они готовы покупать ваш продукт за разную стоимость. Тем, у кого средний чек невысокий, стоит отправлять рассылку с сопутствующими товарами. Для других лучше отправлять простые рассылки, чтобы «не спугнуть».

# %%
rfm_Segment[rfm_Segment['rfm'].isin(['331', '332', '333'])].sort_values('recency', ascending=False).head()
# Out:
#                                       recency  frequency  monetary_value  \
# customer_id
# 73d1cd35-5e5f-4629-8cf2-3fda829d4e58       91         17         21361.0
#
#                                       R_Quartile  F_Quartile  M_Quartile  rfm
# customer_id
# 73d1cd35-5e5f-4629-8cf2-3fda829d4e58           3           3           3  333

# %% [markdown]
# Постоянный клиент, который готов регулярно покупать ваш продукт.VIP-клиенту следует отправлять особые предложения, например, это может быть программа лояльности либо приглашение в VIP-клуб.

# %% [markdown]
# Проанализировать сегменты (количество покупателей, средний чек, основные продукты и категории)

# %% [markdown]
# <font color='black'><b> 4.2 Проанализировать сегменты (количество покупателей, средний чек, основные продукты и категории) </b></font><br>

# %% [markdown]
# Добавим сегмент группы в основную таблицу

# %%
rfm_Segment = rfm_Segment.reset_index()

# %%
rfm_Segment.head()
# Out:
#                             customer_id  recency  frequency  monetary_value  \
# 0  000d6849-084e-4d9f-ac03-37174eaf60c4      106          1           555.0
# 1  001cee7f-0b29-4716-b202-0042213ab038      348          1           442.0
# 2  00299f34-5385-4d13-9aea-c80b81658e1b      108          1           914.0
# 3  002d4d3a-4a59-406b-86ec-c3314357e498      368          1          1649.0
# 4  003bbd39-0000-41ff-b7f9-2ddaec152037      123          1          2324.0
#
#    R_Quartile  F_Quartile  M_Quartile  rfm
# 0           2           1           2  212
# 1           1           1           1  111
# 2           2           1           2  212
# 3           1           1           3  113
# 4           2           1           3  213

# %%
data = data.merge(rfm_Segment[['customer_id', 'rfm']], on='customer_id', how='left')

# %%
data.head()
# Out:
#         date                           customer_id  order_id  \
# 0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price   chek  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0  112.0
#
#         categor    month  rfm
# 0  Сад и огород  2018-10  112
# 1  Сад и огород  2018-10  112
# 2  Сад и огород  2018-10  112
# ...

# %% [markdown]
# Теперь разобьем их на три категории

# %%
list_klient = {
    
    'Ушедшие клиенты':['111', '112', '113','121', '122', '123','131', '132', '133'],
    
    'Неактивные клиенты':['211', '212', '213','221','222','223','231', '232', '233'],
    
    'Постоянные клиенты':['311', '312', '313','321', '322', '323','331', '332', '333']
}

# %%
def categor_klient(rfm):

    for klient, items_klient in list_klient.items():
        for item in items_klient:
            if item in rfm:
                return klient
    return klient

# %%
data['categor_klient'] = data['rfm'].apply(categor_klient)

# %%
data.head()
# Out:
#         date                           customer_id  order_id  \
# 0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price   chek  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0  112.0
#
#         categor    month  rfm   categor_klient
# 0  Сад и огород  2018-10  112  Ушедшие клиенты
# ...

# %% [markdown]
# Количество покупателей в каждом сегменте:

# %%
kol_pok = data.groupby('categor_klient')['customer_id'].nunique()

# %%
print(kol_pok)
# Out:
# categor_klient
# Неактивные клиенты    825
# Постоянные клиенты    797
# Ушедшие клиенты       789
# Name: customer_id, dtype: int64

# %% [markdown]
# Средний чек в каждом сегменте:

# %%
sr_chek_seg = data.groupby('categor_klient')['chek'].mean().round(2)

# %%
print(sr_chek_seg)
# Out:
# categor_klient
# Неактивные клиенты    525.70
# Постоянные клиенты    872.37
# Ушедшие клиенты       773.47
# Name: chek, dtype: float64

# %% [markdown]
# Посмотрим топ три товара у каждой категории покупателей.

# %%
# Подсчёт продаж продуктов по группам клиентов
top_products = data.groupby(['categor_klient', 'product'])['quantity'].sum().reset_index()

# Нахождение топ-3 продуктов для каждой группы
top_products = top_products.sort_values(['categor_klient', 'quantity'], ascending=[True, False]).groupby('categor_klient').head(3)

# Создаём отдельный график для каждой группы клиентов
unique_segments = top_products['categor_klient'].unique()

for segment in unique_segments:
    # Фильтрация данных для текущей группы
    segment_data = top_products[top_products['categor_klient'] == segment]
    
    # Построение горизонтального графика
    plt.figure(figsize=(12, 3))
    sns.barplot(
        data=segment_data, 
        y='product', 
        x='quantity', 
        color='blue'
    )
    
    # Настройки графика
    plt.title(f'Топ-3 продуктов для группы: {segment}', fontsize=16)
    plt.xlabel('Количество продаж', fontsize=12)
    plt.ylabel('Продукт', fontsize=12)
    plt.tight_layout()
    
    # Показать график
    plt.show()

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✏️ Рекомендация тимлида: </b>
#
# Хочется обратить внимание на использование цвета в графике. В текущем исполнении цвет не добавляет дополнительного смысла к данным и может отвлекать от основной информации.
#
# Предлагаю пересмотреть использование цвета и применить его только в случае, если это помогает донести какую-либо важную информацию или улучшает интерпретацию графика.
#
# </div>

# %% [markdown]
# По конкретному товару группы чаще всего покупают Муляж ЯБЛОКО 9 см красное

# %% [markdown]
# Посмотрим топ 3 категории для каждой категории товаров.

# %%
# Подсчёт продаж категорий по группам клиентов
top_categories = data.groupby(['categor_klient', 'categor'])['quantity'].sum().reset_index()

# Нахождение топ-3 категорий для каждой группы
top_categories = top_categories.sort_values(['categor_klient', 'quantity'], ascending=[True, False]).groupby('categor_klient').head(3)

# Создаём отдельный график для каждой группы клиентов
unique_segments = top_categories['categor_klient'].unique()

for segment in unique_segments:
    # Фильтрация данных для текущей группы
    segment_data = top_categories[top_categories['categor_klient'] == segment]
    
    # Построение горизонтального графика
    plt.figure(figsize=(12, 3))
    sns.barplot(
        data=segment_data, 
        y='categor', 
        x='quantity', 
        color='green'
    )
    
    # Настройки графика
    plt.title(f'Топ-3 категории для группы: {segment}', fontsize=16)
    plt.xlabel('Количество продаж', fontsize=12)
    plt.ylabel('Категория', fontsize=12)
    plt.tight_layout()
    
    # Показать график
    plt.show()

# %% [markdown]
# По графику видно, что наиболее популярная категория товара является "Инструменты и гор.жидкости" на втором месте сад и огород.

# %%
data.head()
# Out:
#         date                           customer_id  order_id  \
# 0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price   chek  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0  112.0
#
#         categor    month  rfm   categor_klient
# 0  Сад и огород  2018-10  112  Ушедшие клиенты
# ...

# %% [markdown]
# <font color='black'><b> 4.3 Проанализировать категорию товаров и их сезонность по выделенным сегментам покупателей. </b></font><br>

# %%
# Преобразование 'month' в datetime
if isinstance(data['month'].dtype, pd.PeriodDtype):
    data['month'] = data['month'].dt.to_timestamp()
else:
    data['month'] = pd.to_datetime(data['month'], format='%m.%Y')

# Группировка данных
seasonal_data = data.groupby(['categor_klient', 'categor', 'month'], as_index=False)['quantity'].sum()

# Получаем уникальные категории и сегменты
unique_categories = seasonal_data['categor'].unique()
unique_segments = seasonal_data['categor_klient'].unique()

# Создаём цветовую палитру для всех категорий
palette = sns.color_palette('husl', len(unique_categories))
category_colors = {category: palette[i] for i, category in enumerate(unique_categories)}

# Создаём шкалу времени от сентября 2018 по январь 2020
time_range = pd.date_range(start='2018-10-01', end='2020-01-01', freq='MS')

for segment in unique_segments:
    # Отфильтруем данные для текущего сегмента
    segment_data = seasonal_data[seasonal_data['categor_klient'] == segment]

    # Переходим на индекс по времени и суммируем на случай дубликатов
    segment_data = segment_data.groupby(['month', 'categor'], as_index=False)['quantity'].sum()

    # Убедимся, что временная шкала заполнена полностью
    segment_data = (
        segment_data.set_index('month')
        .pivot(columns='categor', values='quantity')  # Создаём ширину по категориям
        .reindex(time_range)  # Заполняем временной диапазон
        .fillna(0)  # Заполняем пропуски нулями
    )

    # Возвращаем данные в формат длинного DataFrame для построения графика
    segment_data = segment_data.reset_index().melt(id_vars='index', value_name='quantity')
    segment_data.rename(columns={'index': 'month', 'categor': 'category'}, inplace=True)

    # Создаём график
    plt.figure(figsize=(14, 8))
    sns.lineplot(
        data=segment_data,
        x='month',
        y='quantity',
        hue='category',
        marker='o',
        palette=category_colors
    )

    # Настройки графика
    plt.title(f'Сезонность продаж по категории товаров: {segment}', fontsize=16)
    plt.xlabel('Месяц', fontsize=12)
    plt.ylabel('Количество продаж', fontsize=12)
    plt.legend(title='Категории товаров', fontsize=10)
    plt.xticks(rotation=45)
    plt.xlim(pd.to_datetime('2018-10-01'), pd.to_datetime('2020-01-01'))
    plt.tight_layout()

    # Показать график
    plt.show()

# %% [markdown]
# <div id="div_id20" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v4] : </b>
#
# <s>[⬆ Ошибка №20](#2)
#
# Графики доработаны не в полном объеме
#
#     Период по оси X должен совпадать на всех графиках - от 2018-10 до 2020-01. Таким образом будет наглядно видно, где ушедшие, а где активные.
#
# </div>

# %% [markdown]
# <div id="div_id18" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v3] : </b>
#
# <s>[⬆ Ошибка №18](#3)
#
#
# Если ты проводишь серию визуальных сравнение, то цветовая схема должна совпадать. А у тебя категориям соответствуют разные цвета на разных графиках, что вызывает путаницу в визуальном плане.
#
# ---
#
# Период по оси X должен совпадать на всех графиках - от 2018-10 до 2020-01. Таким образом будет наглядно видно, где ушедшие, а где активные.
#
# </div>

# %% [markdown]
# <div id="div_id11" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание ревьюера [v2]: </b>
#
# <s>[⬆ Ошибка №11](#2)
#
# У тебя данные за разные годы с 2018 по 2020. Группируя по месяцам, ты суммируешь показатели по месяцам за разные годы, что искажает картину
#
# ---
#
# В следствии этого, у тебя на графике Ушедшие клиенты активны в течении года
#
# </div>

# %% [markdown]
# <div id="div_id6" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №6](#1)
#
# К сожалению, столкнулся с проблемой воспроизводимости кода. Проверка кода на воспроизводимость - это ключевой момент, который не стоит пропускать.
#
# ![image.png](attachment:image.png)
#
# Настоятельно рекомендую всегда перед отправкой своего решения на проверку запускать код через Kernel -> Restart & Run All.
#
# Это поможет избежать неприятных ситуаций, когда что-то не работает, и увеличит вероятность того, что твой проект будет принят.
#
# </div>

# %% [markdown]
# Сезонность продаж категорий товаров по сегментированным покупателям. На данном графики видно, что неактивные клиенты имеют явную сезонность с марта по октябрь. В этот период продажи такой категории резко вырастают. Причем только в категории товаров инструменты и гор.жидкости и сад и огород, но инструменты и гор.жидкости растет сильнее. Те же категории растут и упостоянных клиентов, но в период по ноябрь. У ушедших клиентов растет только Инструмент и гор.жидкости причем значимой сезонности мы не наблюдаем.

# %% [markdown]
# Вывод по шагу №4: В шаге номер 4 мы сегментировали пользователей на три группы: 'Ушедшие клиенты', 'Неактивные клиенты', 'Постоянные клиенты'. для каждой группы мы описали краткую характеристику клиенту, и дали рекомендации как привлеч данного клиента. После разделения на три группы мы сделали анализ данных групп и посмотрели некоторые метрики.
# Количество покупателей в каждой группе:
# Неактивные клиенты    809
# Постоянные клиенты    793
# Ушедшие клиенты       787
# Средний чек по группам:
# Неактивные клиенты    439.44
# Постоянные клиенты    845.33
# Ушедшие клиенты       673.44
#
#
# А так же построили график топ 3 товара для каждого сегмента и топ 3 категории товара для каждого сегмента. По графику видно, что наиболее популярная категория товара является "Инструменты и гор.жидкости". Данная категория лидирует во всех категориях покупателей. По конкретному товару группы чаще всего покупают пеларгонию.
# Далее мы проанализировали сезонность продаж категорий товаров по сегментированным покупателям. На данном графики видно, что неактивные клиенты имеют явную сезонность с марта по июль. В этот период продажи такой категории резко вырастают. Причем только в категории товаров Инструмент и гор.жидкости и сад и огород, но Инструмент и гор.жидкости растет сильнее. Те же категории растут и у постоянных клиентов, но в период по ноябрь. У ушедших клиентов растет только Инструмент и гор.жидкости причем значимой сезонности мы не наблюдаем.

# %% [markdown]
# # Шаг 5. Сформулировать гипотезы по сегментам.

# %% [markdown]
# Первая гипотеза: Проверка разницы среднего чека между сегметами: H0 - Средний чек различных сегметов равен. H - Средний чек различных сегментов не равны.
#
# Вторая гипотиза: Проверка разницы выручки между сегментами:H0 - выручка различных сегметов пользователей равна. H- Выручка сегментов пользователей не равна.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Очень хорошо, что не забываешь про формулировку гипотез. Это важный пункт в подобного рода задачах.
#
# </div>

# %% [markdown]
# Первая гипотеза:

# %% [markdown]
# Посчитаем средний чек для каждого клиента и категории.

# %%
sr_chek_k = data.groupby(['customer_id', 'categor_klient'])['chek'].mean().reset_index()

# Выводим результат
sr_chek_k.head()
# Out:
#                             customer_id      categor_klient     chek
# 0  000d6849-084e-4d9f-ac03-37174eaf60c4  Неактивные клиенты   138.75
# 1  001cee7f-0b29-4716-b202-0042213ab038     Ушедшие клиенты   442.00
# 2  00299f34-5385-4d13-9aea-c80b81658e1b  Неактивные клиенты   914.00
# 3  002d4d3a-4a59-406b-86ec-c3314357e498     Ушедшие клиенты  1649.00
# 4  003bbd39-0000-41ff-b7f9-2ddaec152037  Неактивные клиенты  2324.00

# %% [markdown]
# Будем проверять гипотезу сравнения среднего чека поочередно сравнивая каждую категорию т тестом.

# %% [markdown]
# Метод Бонферрони предлагает использовать для проверки каждой гипотезы уровень значимости, равный alpha / m, где m — количество гипотез. Это позволяет контролировать FWER на уровне, не превосходящем alpha. Метод Бонферрони прост в реализации, но уступает в мощности другим поправкам.

# %% [markdown]
# Теста у нас 2, поэтому будем делить уровень значимости на 2.

# %%
gr_1 = sr_chek_k.loc[sr_chek_k.categor_klient == 'Неактивные клиенты', 'chek'] 

gr_2 = sr_chek_k.loc[sr_chek_k.categor_klient == 'Постоянные клиенты', 'chek'] 


results = st.ttest_ind(gr_1, 
                       gr_2,
                       alternative='two-sided')

alpha = 0.05/2

print(results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу, данные категории различаются по среднему чеку')
else:
    print('Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по среднему чеку.')
# Out:
# 0.06649788236052813
# Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по среднему чеку.

# %%
gr_1 = sr_chek_k.loc[sr_chek_k.categor_klient == 'Неактивные клиенты', 'chek'] 

gr_3 = sr_chek_k.loc[sr_chek_k.categor_klient == 'Ушедшие клиенты', 'chek'] 


results = st.ttest_ind(gr_1, 
                       gr_3,
                       alternative='two-sided')

alpha = 0.05/2

print(results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу, данные категории различаются по среднему чеку')
else:
    print('Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по среднему чеку.')
# Out:
# 0.45189340663169686
# Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по среднему чеку.

# %%
gr_2 = sr_chek_k.loc[sr_chek_k.categor_klient == 'Постоянные клиенты', 'chek']  

gr_3 = sr_chek_k.loc[sr_chek_k.categor_klient == 'Ушедшие клиенты', 'chek'] 


results = st.ttest_ind(gr_2, 
                       gr_3,
                       alternative='two-sided')

alpha = 0.05/2

print(results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу, данные категории различаются по среднему чеку')
else:
    print('Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по среднему чеку.')
# Out:
# 0.0037096307737304393
# Отвергаем нулевую гипотезу, данные категории различаются по среднему чеку

# %% [markdown]
# Вторая гипотиза:

# %%
viruch_k = data.groupby(['customer_id', 'categor_klient'])['chek'].sum().reset_index()

# Выводим результат
viruch_k.head()
# Out:
#                             customer_id      categor_klient    chek
# 0  000d6849-084e-4d9f-ac03-37174eaf60c4  Неактивные клиенты   555.0
# 1  001cee7f-0b29-4716-b202-0042213ab038     Ушедшие клиенты   442.0
# 2  00299f34-5385-4d13-9aea-c80b81658e1b  Неактивные клиенты   914.0
# 3  002d4d3a-4a59-406b-86ec-c3314357e498     Ушедшие клиенты  1649.0
# 4  003bbd39-0000-41ff-b7f9-2ddaec152037  Неактивные клиенты  2324.0

# %%
gr_1 = viruch_k.loc[viruch_k.categor_klient == 'Неактивные клиенты', 'chek'] 

gr_2 = viruch_k.loc[viruch_k.categor_klient == 'Постоянные клиенты', 'chek'] 


results = st.ttest_ind(gr_1, 
                       gr_2,
                       alternative='two-sided')

alpha = 0.05/2

print(results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу, данные категории различаются по выручке')
else:
    print('Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по выручке.')
# Out:
# 0.03854016453620485
# Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по выручке.

# %%
gr_1 = viruch_k.loc[viruch_k.categor_klient == 'Неактивные клиенты', 'chek'] 

gr_3 = viruch_k.loc[viruch_k.categor_klient == 'Ушедшие клиенты', 'chek'] 


results = st.ttest_ind(gr_1, 
                       gr_3,
                       alternative='two-sided')

alpha = 0.05/2

print(results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу, данные категории различаются по выручке')
else:
    print('Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по выручке.')
# Out:
# 0.42008178802413987
# Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по выручке.

# %%
gr_2 = viruch_k.loc[viruch_k.categor_klient == 'Постоянные клиенты', 'chek']  

gr_3 = viruch_k.loc[viruch_k.categor_klient == 'Ушедшие клиенты', 'chek'] 


results = st.ttest_ind(gr_2, 
                       gr_3,
                       alternative='two-sided')

alpha = 0.05/2

print(results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу, данные категории различаются по выручке')
else:
    print('Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по выручке.')
# Out:
# 0.42254417471892436
# Не удалось отвергнуть нулевую гипотезу, данные клиенты очень похожи по выручке.

# %% [markdown]
# В итоге у меня получилось, что различаются данные категории только по среднему чеку ушедшие и постоянные клиенты. Все остальные сравнения не отвергают нулевую гипотезу.

# %% [markdown]
# <div id="div_id21" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v4] : </b>
#
# <s>[⬆ Ошибка №21](#4)
#
# `alternative = 'greater'` - в формулировке гипотез говорится о различиях между сегментами. Различия могут быть и в меньшую сторону. У тебя сейчас идет односторонняя проверка
#
# ---
#
# У тебя выполняются два отдельных теста для разных показателей по одним и тем же сегментам.
#
# В данной ситуации следует применить поправку на множественную проверку гипотез.
#
# </div>

# %% [markdown]
# <div id="div_id19" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v3] : </b>
#
# <s>[⬆ Ошибка №19](#3)
#
#
# Ты и в первой и во второй гипотезе подставляшеь одни и те же данные. В чем разница то между ними?
#
# ![image-3.png](attachment:image-3.png)
#
# p-value даже совпадает.
#
# Будь внимательнее, пожалуйста
#
# </div>

# %% [markdown]
# <div id="div_id12" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №12](#2)
#
# `['total_price']` -  это не средний чек.
#
# Средний чек рассчитывается через `order_id`
#
# </div>

# %% [markdown]
# <div id="div_id13" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №13](#2)
#
# У тебя что
#
#     # Рассчитываем выручку (общий доход) для каждого заказа
#     data['revenue'] = data['quantity'] * data['price']
#
# что
#
#     # Рассчитываем общий чек для каждого заказа
#     data['total_price'] = data['quantity'] * data['price']
#
# по расчету одинаковы.
#
# Определись, что ты считаешь в каждой из гипотез.
#
# </div>

# %% [markdown]
# <div id="div_id14" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2]: </b>
#
# <s>[⬆ Ошибка №14](#2)
#
# После проведения ANOVA теста, если отвергается нулевая гипотеза (то есть установлено, что есть различия между средними значениями в сегментах покупателей), необходимо уточнить, между какими именно сегментами.
#
# ANOVA показывает только наличие различий в целом, но не указывает, какие именно сегменты отличаются друг от друга.
#
# </div>

# %% [markdown]
# # Общий вывод:

# %% [markdown]
# В шаге 1 мы загрузили датасет о транзакциях интернет-магазина. Записали его в переменную data. После чего посмотрели обшую информацию датафрейма. При рассмотрении общей информации можно сказать что датасет имеет 7473 строк.
#
# В шаге 2 мы заменили названия столбцов (привели их к нижнему регистру). Проверили количество пропусков в каждом датасете, их мы не обнаружили. Проверили количество явных дубликатов их мы не обнаружили. Проверили на не явные дубликаты по id пользователя, продукту и дате, и обнаружили дубликаты, явно дублирующие сами себя. Мы решили их просто удалить, так это не повлияет на наше иследование.
#
# В шаге 3 мы проведем исследовательский анализ данных: провели категоризацию товаров, проверили динамику выручки, средний чек и его динамеку, помесячную динамику средней выручки с покупателя. Можно сделать вывод, что у магазина есть проблемы с продажами: выручка уменьшается по сравнению с октябрем 2018 года, средний чек так же продолжает падение и в последние три месяца на минимуме. Если посмотреть на динамику среднего чека с покупателя то видим, что она заметна увеличилась в июне, но после этого сильно упала и к ноябрю оказалась на минимуме.
#
# В шаге 4 мы расмотрели основные вопросы исследования:
# мы сегментировали пользователей на три группы: 'Ушедшие клиенты', 'Неактивные клиенты', 'Постоянные клиенты'. для каждой группы мы описали краткую характеристику клиенту, и дали рекомендации как привлеч данного клиента. После разделения на три группы мы сделали анализ данных групп и посмотрели некоторые метрики.
# Количество покупателей в каждой группе:
# Неактивные клиенты    809
# Постоянные клиенты    793
# Ушедшие клиенты       787
# Средний чек по группам:
# Неактивные клиенты    439.44
# Постоянные клиенты    845.33
# Ушедшие клиенты       673.44
# А так же построили график топ 3 товара для каждого сегмента и топ 3 категории товара для каждого сегмента. По графику видно, что наиболее популярная категория товара является "Инструмент и гор.жидкости". Данная категория лидирует во всех категориях покупателей. По конкретному товару группы разделились: Постоянные клиенты чаще всего покупают шпингалет, неактивные клиенты чаще всего покупают вантус с деревяной ручкой и ушедшие клиенты чаще всего покупают крепеж для пружины дверей. Далее мы проанализировали сезонность продаж категорий товаров по сегментированным покупателям. На данном графики видно, что неактивные клиенты имеют явную сезонность с марта по июль. В этот период продажи такой категории резко вырастают. Причем только в категории товаров Инструмент и гор.жидкости и сад и огород, но Инструмент и гор.жидкости растет сильнее. Те же категории растут и упостоянных клиентов, но в период по ноябрь. У ушедших клиентов растет только Инструмент и гор.жидкости причем значимой сезонности мы не наблюдаем.
#
#
# В шаге 5 мы проверили две гипотезы:
# Первая гипотеза: Проверка разницы среднего чека между сегметами: H0 - Средний чек различных сегметов равен. H - Средний чек различных сегментов не равны.
# Вторая гипотиза: Проверка разницы выручки между сегментами:H0 - выручка различных сегметов пользователей равна. H- Выручка сегментов пользователей не равна.
# В итоге у меня получилось, что различаются данные категории только по среднему чеку Неактивные клиенты и постоянные клиенты. Все остальные сравнения не отвергают нулевую гипотезу.

# %% [markdown]
# Учитывая все выше изложенное можно дать рекомендации:
# Для группы покупателей 'Ушедшие клиенты' мы рекомендуем попытаться вернуть таких клиентов. Это можно сделать с помощью рассылки, в которой будет информация о скидках, программы лояльности и так далее.
# Для группы покупателей 'Неактивные клиенты' мы рекомендуем  обязательно выяснить, что случилось, почему клиент перестал у вас покупать. Вернуть таких клиентов можно с помощью опроса либо акционных предложений.
# Для группы покупателей 'Постоянные клиенты' мы рекомендуем отправлять письма со специальными предложениями, которые могут заинтересовать клиента.

# %% [markdown]
# Рекомендации по месяцам отправки предложений:
#
#
# Неактивные клиенты:
# Январь - предлагаем товары из категории инструменты и гор.жидкости.
# Февраль - предлагаем товары из категории сад и огород.
# Март - предлагаем товары из категории сад и огород, инструменты и гор.жидкости.
# Апрель - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, украшение дома.
# Май - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, украшение дома.
# Июнь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, украшение дома.
# Июль - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, товары для ванной.
# Август - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, домашний уют.
# Сентябрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, кухонные аксессуары.
# Октябрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, товары для ванной.
#
# Ушедшие клиенты:
# Январь - предлагаем товары из категории инструменты и гор.жидкости, сад и огород, кухонные аксессуары.
# Февраль - предлагаем товары из категории сад и огород, кухонные аксессуары, товары для ванной.
# Март - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, товары для ванной.
# Апрель - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, товары для ванной.
# Октябрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, кухонные аксессуары.
# Ноябрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, кухонные аксессуары.
# Декабрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, кухонные аксессуары.
#
# Постоянные клиенты:
# Январь - предлагаем товары из категории инструменты и гор.жидкости, сад и огород, товары для ванной.
# Февраль - предлагаем товары из категории инструменты и гор.жидкости, сад и огород, товары для ванной.
# Март - предлагаем товары из категории инструменты и гор.жидкости, сад и огород, товары для ванной.
# Апрель - предлагаем товары из категории инструменты и гор.жидкости, сад и огород, товары для ванной.
# Май - предлагаем товары из категории инструменты и гор.жидкости, сад и огород, товары для ванной.
# Июнь - предлагаем товары из категории инструменты и гор.жидкости, сад и огород, товары для ванной.
# Июль - предлагаем товары из категории инструменты и гор.жидкости, товары для ванной, украшение дома.
# Август - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, украшение дома.
# Сентябрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, украшение дома.
# Октябрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, украшение дома.
# Ноябрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, украшение дома.
# Декабрь - предлагаем товары из категории сад и огород, инструменты и гор.жидкости, товары для ванной.

# %% [markdown]
# <div id="div_id" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> НАПОМИНАНИЕ [v4]: </b>
#
#
# После того как ты внесёшь необходимые исправления замечаний, обязательно пересмотри и актуализируй итоговое заключение.
#
# </div>

# %% [markdown]
# <div id="div_id15" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2]: </b>
#
# <s>[⬆ Ошибка №15](#2)
#
# После того как ты внесёшь необходимые исправления замечаний, обязательно пересмотри и актуализируй итоговое заключение.
#
# ---
#
# Давай переоформим рекомендации в более наглядный вид.
#
#
# **Каким клиентам (каким сегментам покупателей) когда (в какой месяц) какие категории товара рассылать в рекламных предложениях.**
#
#
#     Сегмент такой-то:
#
#     Январь - предлагаем товары из такой то категории
#
#     Февраль - предлагаем товары из такой то категории
#
#     Март - предлагаем товары из такой то категории
#
#     ...
#
# </div>
